# %%
state0 = [2,6,3,
         1,8,7,
         5,4,"x"
        ]

state1 = ["x",6,3,
         1,8,7,
         5,4,2
        ]

state3 = [6,"x",3,
         1,8,7,
         5,4,2
        ]

# %%
def slideRight (array):
    arrayCpy = array # to dont change original array
    print (arrayCpy)
    for i in arrayCpy:
        if i is "x": # encontra o vazio
            # se for resto 0 ou 2, entao eh uma "borda"
            if (arrayCpy.index(i)) % 3 == 0:
                # if 0 cant slide to left 
                xPos = arrayCpy.index(i)
                number = arrayCpy.index(i) + 3 # = 3
                toChange = arrayCpy[number]
                arrayCpy[number] = "x"
                arrayCpy[xPos] = toChange
                for i in arrayCpy:
                    print (i)
            elif (array.index(i)) % 3 == 2:
                # if 2 cant slide to right 
                print ("borda")

# %%
def slideRight (array):
    x_pos = array.index("x")
    arrayCpy = list(array) # dont change original array

    print (x_pos)
        
    if x_pos % 3 != 2:
        numberPos =

# %%
slideRight(state1)
# Out:
# 0
